# %% [markdown]
# # Evelyn Pu

# %% [markdown]
# ## Research question/interests
#
# My personal interest is in the analysis of bike-sharing user demographics. My analysis may include ***whether these two types of users( casual and registered) share the same user number trends***, as well as the analysis of the characteristics of each of them and the percentage of total users. I am taking a statistics course this term, which has inspired me, and I think I can use some statistical skills to accomplish this task.
#
#
# To figure out this, I might analyze：
#
# 1. for both types of users, is there always more users of one type? -I would like to compare the respective Numeric values and use an int variable or bool variable to record the number of times the number of users of one type is greater than the number of users of the other type, and if so this number is added to 1 or defined as true.(but I am not sure which is better and will try in a later analysis)
# Possible details to include:
# (1) Assume an int variable named x to record the number of times a class of users is more than another class of users.
# (2) Add a column named 'IFregMORE', of type boolean.
# (3) Combine while/for Loop and if statements to determine true when the number of users of one class is more than the number of users of another class, and apply this condition to each rows loop.
# (4) At the end of the loop, use count() to count the number of times true and assign it to x to determine if there are always more users of one category than another.
# (5) (Optional) Calculate the statistics of the two types of users, such as mean, median, min and max, etc.
#
#
# 2. Are the usage habits of the two types of users the same? For example, using the change in the number of users in a certain season, a certain time of day, to analyze whether they have the same willingness to use in a certain season/day/time of day. Here, I plan to use histograms or scatter plots to look at the data.
# Possible details to include:
# (1) add two new columns named 'casSeason' and 'regSeason'
# (2) Calculate the total number of users in both categories for each season, using columns= 'season' as index.
# (3) Make a chart with visual data for observation.

# %%
import pandas as pd

# %%
day = pd.read_csv("../data/raw/day.csv")
day
# Out:
#      instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0          1  2011-01-01       1   0     1        0        6           0
# 1          2  2011-01-02       1   0     1        0        0           0
# 2          3  2011-01-03       1   0     1        0        1           1
# 3          4  2011-01-04       1   0     1        0        2           1
# 4          5  2011-01-05       1   0     1        0        3           1
# ..       ...         ...     ...  ..   ...      ...      ...         ...
# 726      727  2012-12-27       1   1    12        0        4           1
# 727      728  2012-12-28       1   1    12        0        5           1
# 728      729  2012-12-29       1   1    12        0        6           0
# 729      730  2012-12-30       1   1    12        0        0           0
# 730      731  2012-12-31       1   1    12        0        1           1
#
#      weathersit      temp     atemp       hum  windspeed  casual  registered  \
# ...

# %%
hour=pd.read_csv("../data/raw/hour.csv")
hour
# Out:
#        instant      dteday  season  yr  mnth  hr  holiday  weekday  \
# 0            1  2011-01-01       1   0     1   0        0        6
# 1            2  2011-01-01       1   0     1   1        0        6
# 2            3  2011-01-01       1   0     1   2        0        6
# 3            4  2011-01-01       1   0     1   3        0        6
# 4            5  2011-01-01       1   0     1   4        0        6
# ...        ...         ...     ...  ..   ...  ..      ...      ...
# 17374    17375  2012-12-31       1   1    12  19        0        1
# 17375    17376  2012-12-31       1   1    12  20        0        1
# 17376    17377  2012-12-31       1   1    12  21        0        1
# 17377    17378  2012-12-31       1   1    12  22        0        1
# 17378    17379  2012-12-31       1   1    12  23        0        1
#
#        workingday  weathersit  temp   atemp   hum  windspeed  casual  \
# 0               0           1  0.24  0.2879  0.81     0.0000       3
# ...
